# %% [markdown]
# <a href="https://colab.research.google.com/github/YarkoMarko/Analys/blob/main/module2/%D0%94%D0%97_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Імпорт модулів та даних

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("https://raw.githubusercontent.com/HalyshAnton/IT-Step-Pyton-AI/main/module2/data/ship_passengers.csv",
                 index_col="Unnamed: 0")

# %%
df
# Out:
#      pclass     sex   age  sibsp  parch     fare embarked
# 0         3    male  22.0      1      0   7.2500        S
# 1         1  female  38.0      1      0  71.2833        C
# 2         3  female  26.0      0      0   7.9250        S
# 3         1  female  35.0      1      0  53.1000        S
# 4         3    male  35.0      0      0   8.0500        S
# ..      ...     ...   ...    ...    ...      ...      ...
# 886       2    male  27.0      0      0  13.0000        S
# 887       1  female  19.0      0      0  30.0000        S
# 888       3  female   NaN      1      2  23.4500        S
# 889       1    male  26.0      0      0  30.0000        C
# 890       3    male  32.0      0      0   7.7500        Q
#
# [891 rows x 7 columns]

# %% [markdown]
# # Завдання
# Проведіть аналіз даних пасажирів. Включіть
#
# * аналіз числових ознак
# * аналіз категоріальних ознак
# * перевірку викидів
#
# В результаті як коментар опишіть дані(що на що впливає\не впливає і як, можливо якихось даних надто мало і потрібно більше даних, тощо)

# %%
df.describe()
# Out:
#            pclass         age       sibsp       parch        fare
# count  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.836071   14.526497    1.102743    0.806057   49.693429
# min      1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      3.000000   38.000000    1.000000    0.000000   31.000000
# max      3.000000   80.000000    8.000000    6.000000  512.329200

# %%
for column in df.select_dtypes("number"):
  df[column].plot(kind="box", vert=False, figsize=(14, 6))
  plt.show()

# %%
columns_n = df.select_dtypes(include="number").columns
corr = df[columns_n].corr(method="spearman")
fig = plt.figure(figsize=(8, 8))
plt.matshow(corr, cmap="RdBu", fignum=fig.number)
plt.xticks(range(len(corr.columns)), corr.columns, rotation="vertical")
plt.yticks(range(len(corr.columns)), corr.columns)
plt.colorbar()

# %%
"Як можете побачити - дані між собою не дуже лінійні, їх самих доволі мало та є доволі багато викидів"
